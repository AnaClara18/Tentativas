# %% [markdown]
# ## Tentando desenvolver em python e pandas

# %%
import pandas as pd
# Out:
# /tmp/ipykernel_4252/217833862.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('/home/anaclara/Documents/Tentativas Ana/dados_abertos/dados_abertos___estudantes_da_graduacao_2024-02-15T15_15_39.003984-03_00.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286665 entries, 0 to 286664
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   registro_academico          286665 non-null  int64
#  1   curso                       286665 non-null  object
#  2   semestre_letivo_referencia  286665 non-null  object
#  3   ano_letivo_referencia       286665 non-null  object
#  4   situacao_estudante          286665 non-null  object
#  5   semestre_letivo_ingresso    286665 non-null  object
#  6   forma_ingresso              286665 non-null  object
#  7   forma_ingresso_tipo         286665 non-null  object
#  8   codigo_oferta_curso         286665 non-null  object
#  9   codigo_inep                 286665 non-null  int64
#  10  curso_turno                 286665 non-null  object
#  11  nome_matriz_curricular      286665 non-null  int64
#  12  titulo_academico            286665 non-null  object
# ...

# %%
df_alunos = df[df['forma_ingresso'].str.contains('SISU', case=False, na=False)]

display(df_alunos)
# Out:
#         registro_academico                                              curso  \
# 0                202325010  Bacharelado Interdisciplinar em Inovação, Ciên...
# 1                202325009  Bacharelado Interdisciplinar em Inovação, Ciên...
# 2                202325008  Bacharelado Interdisciplinar em Inovação, Ciên...
# 3                202325007  Bacharelado Interdisciplinar em Inovação, Ciên...
# 4                202325006  Bacharelado Interdisciplinar em Inovação, Ciên...
# ...                    ...                                                ...
# 266288           201010007                                          Agronomia
# 266289           201010007                                          Agronomia
# 266290           201010007                                          Agronomia
# 266291           201010007                                          Agronomia
# 266292           201010007                                          Agronomia
#
# ...

# %%
df.sample(6)
# Out:
#         registro_academico                               curso  \
# 192332           201311546  Engenharia de Controle e Automação
# 18542            202110643                 Engenharia Agrícola
# 45964            201911271                           Zootecnia
# 93414            201711915                      ABI Engenharia
# 93370            201711920                           Pedagogia
# 10092            202210127                          Matemática
#
#        semestre_letivo_referencia ano_letivo_referencia situacao_estudante  \
# 192332                     2015/2            2015-01-01              Ativo
# 18542                      2021/2            2021-01-01              Ativo
# 45964                      2022/2            2022-01-01              Ativo
# 93414                      2018/2            2018-01-01              Ativo
# 93370                      2019/2            2019-01-01              Ativo
# ...

# %%
df_agrupar = df.groupby('curso').size().reset_index(name='Quantidade')

# %%
display(df_agrupar)
display(df_agrupar.info())
# Out:
#                                                 curso  Quantidade
# 0                                 ABI Educação Física         676
# 1                                      ABI Engenharia       15392
# 2                                          ABI Letras         117
# 3                                       Administração        9040
# 4                            Administração Piloto EAD         559
# 5                               Administração Pública       18274
# 6                                           Agronomia       26647
# 7   Bacharelado Interdisciplinar em Inovação, Ciên...         519
# 8                               Ciência da Computação        9133
# 9                                 Ciências Biológicas       11093
# 10                                            Direito       10813
# 11                                    Educação Física       12706
# 12                                Engenharia Agrícola        6637
# ...

# %%
df_encontar = df.loc[df['registro_academico'] == 202325010]

display(df_encontar)
# Out:
#    registro_academico                                              curso  \
# 0           202325010  Bacharelado Interdisciplinar em Inovação, Ciên...
#
#   semestre_letivo_referencia ano_letivo_referencia situacao_estudante  \
# 0                     2023/2            2023-01-01              Ativo
#
#   semestre_letivo_ingresso forma_ingresso forma_ingresso_tipo  \
# 0                   2023/2    SiSU (Enem)             Regular
#
#   codigo_oferta_curso  codigo_inep curso_turno  nome_matriz_curricular  \
# 0              GCT039      1598889    Integral                  202302
#
#   titulo_academico curso_modalidade situacao_nome  \
# 0      Bacharelado       Presencial   Matriculado
#
#                            situacao_descricao situacao_censo          campus  \
# 0  Discente matriculado regularmente no curso       Cursando  Campus Paraíso
#
#   sistema_origem         data_atualizacao_dw
# 0       SIG-UFLA  2024-02-15T02:06:27.414384

# %%
df_situacao = df[df['situacao_nome'].str.contains('desistiu do curso', case=False, na=False)]

display(df_situacao)
# Out:
#         registro_academico                                              curso  \
# 2                202325008  Bacharelado Interdisciplinar em Inovação, Ciên...
# 12               202321151                                Ciências Biológicas
# 30               202321133                              Ciência da Computação
# 41               202321122                                ABI Educação Física
# 46               202321117                                            Direito
# ...                    ...                                                ...
# 286258           200510276                                Ciências Biológicas
# 286321           200510132                               Engenharia Florestal
# 286371           200420345                                Engenharia Agrícola
# 286459           200420110                                Engenharia Agrícola
# 286664           199910244                               Engenharia Florestal
#
# ...
